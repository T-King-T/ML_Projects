# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive

drive.mount('/content/drive', force_remount=True)

stu = pd.read_csv('drive/My Drive/students.csv')
# Out:
# Mounted at /content/drive

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       100 non-null    int64
#  1   Sex              100 non-null    object
#  2   Age              100 non-null    int64
#  3   Study_Hours      100 non-null    int64
#  4   Previous_Scores  100 non-null    int64
#  5   Final_Score      100 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# The above output represents each column name found with the data set, as well as the count of non-null data with each column and their respective data type.

# %%
stu.describe()
# Out:
#        Student_ID        Age  Study_Hours  Previous_Scores  Final_Score
# count  100.000000  100.00000   100.000000       100.000000   100.000000
# mean    50.500000   17.99000     5.630000        82.000000    85.300000
# std     29.011492    1.46677     2.725321        11.218671    11.467565
# min      1.000000   16.00000     2.000000        60.000000    54.000000
# 25%     25.750000   17.00000     3.000000        74.000000    75.000000
# 50%     50.500000   18.00000     5.000000        83.000000    88.000000
# 75%     75.250000   19.00000     8.000000        92.000000    94.000000
# max    100.000000   20.00000    10.000000       100.000000   100.000000

# %% [markdown]
# The above output represents a list of measurements regarding the dataset. from top to bottom. The total data count for each column. The mean measurement of the data. The Standard? of each set of data. The minimum value in the column. the the 25th, 50th, and 75th percentiles of the data and the maximum value in each column.

# %%
stu['Sex'].value_counts()
# Out:
# Female    56
# Male      44
# Name: Sex, dtype: int64

# %% [markdown]
# Above depicts the ratio of females to males within accounted for within the dataset.

# %%
stu['Study_Hours'].sum()/stu['Student_ID'].count()
# Out:
# 5.63

# %% [markdown]
# The Above represents the average amount to time students as a whole spent studying between their previous and final grades.

# %%
stu.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'Student_ID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Study_Hours'}>,
#         <Axes: title={'center': 'Previous_Scores'}>],
#        [<Axes: title={'center': 'Final_Score'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Above are the histograms showing the column data. The number of students in each age group, the number of students that study different amounts of hours, the number of students that scored what scores previously and then their final scores. The last two depict the increase in scores.

# %%
stu.plot(kind='scatter', x='Age',y='Previous_Scores', alpha=0.5)
stu.plot(kind='scatter', x='Age',y='Final_Score', alpha=0.5)
# Out:
# <Axes: xlabel='Age', ylabel='Final_Score'>

# %% [markdown]
# The above scatter plots help to visualize how students of certain ages, grades changed. The darker a dot is the more students of that age got that score. From the previous to the final scorewe can observe a general shift upward across all ages.
